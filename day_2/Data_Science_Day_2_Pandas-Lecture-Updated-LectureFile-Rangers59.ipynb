# %% [markdown]
# # Data Science Pandas

# %% [markdown]
# ## Tasks Today:
#
# 0) <b>Pre-Work</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Numpy Random Sampling
#
# 1) <b>Pandas</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Importing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Tabular Data Structures <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - from_dict() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - read_csv() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) <b>In-Class Exercise #1</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Accessing Data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Indexing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - df.loc <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - keys() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Slicing a DataFrame <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Built-In Methods <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - head() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - tail() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - shape <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - describe() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - sort_values() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - .columns <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) <b>In-Class Exercise #2</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Filtration <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Conditionals <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Subsetting <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) Column Transformations <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Generating a New Column w/Data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - User Defined Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) Aggregations <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - groupby() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Type of groupby() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - mean() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - groupby() w/Multiple Columns <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - drop_duplicates() <br>

# %% [markdown]
# ## Keywords for the day:
# - DataFrame
# - Series

# %% [markdown]
# ## Numpy Random Sampling

# %%
import numpy as np

# A single call generates a single random number
print('Here is a random number: %s' % np.random.uniform())
print(f'Here is a random number: {np.random.uniform()}')

# You can also pass some bounds
print('Here is a random number between 0 and 1 Million: %s' % np.random.uniform(0, 1e6))

# You can also generate a bunch of random numbers all at once
print('Here are 3 random numbers between 0 and 1 Million: %s' % np.random.uniform(0, 1e6, 3))

# Even matrices and tensors with weird shapes
print('Here is a 3x3 matrix of random numbers between 0 and 1 Million: \n %s' % np.random.uniform(0, 1e6, (3, 3)))

# instead of float values, generating random integers
print('Using Random Integer: %s' % np.random.randint(0, 10, 4))
# Out:
# Here is a random number: 0.1982477708740027
# Here is a random number: 0.78574829966823
# Here is a random number between 0 and 1 Million: 835706.5047548842
# Here are 3 random numbers between 0 and 1 Million: [691262.3208722   37359.36168673    928.066779  ]
# Here is a 3x3 matrix of random numbers between 0 and 1 Million:
#  [[775911.21283737 661694.07910789 263990.87797541]
#  [938385.07815044 767354.63453226 575069.76541268]
#  [465718.43944451 632967.89061466 982726.38361054]]
# Using Random Integer: [6 5 0 7]

# %% [markdown]
# ## Pandas <br>
#
# <p>Pandas is a flexible data analysis library built on top of NumPy that is excellent for working with tabular data. It is currently the de-facto standard for Python-based data analysis, and fluency in Pandas will do wonders for your productivity and frankly your resume. It is one of the fastest ways of getting from zero to answer in existence. </p>
#
# <ul>
#     <li>Pandas is a Python module, written in C. The Pandas module is a high performance, highly efficient, and high level data analysis library. It allows us to work with large sets of data called dataframes.</li>
#     <li>Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.)</li>
#     <li>Dataframe = Spreadsheet (has column headers, index, etc.)</li>
# </ul>

# %% [markdown]
# ### Importing

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/vincent/opt/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/vincent/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/vincent/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /Users/vincent/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in /Users/vincent/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
import pandas as pd

# always use pd, standard for data science

# %% [markdown]
# ### Tabular data structures <br>
# <p>The central object of study in Pandas is the DataFrame, which is a tabular data structure with rows and columns like an excel spreadsheet. The first point of discussion is the creation of dataframes both from native Python dictionaries, and text files through the Pandas I/O system.</p>

# %%
names = ['Alice',
         'Bob',
         'James',
         'Beth', 
         'John', 
         'Sally',
         'Richard', 
         'Lauren',
         'Brandon', 
         'Sabrina']

ages = np.random.randint(18,35,len(names))

my_people = {
    'names': names,
    'ages': ages
}

my_people
# Out:
# {'names': ['Alice',
#   'Bob',
#   'James',
#   'Beth',
#   'John',
#   'Sally',
#   'Richard',
#   'Lauren',
#   'Brandon',
#   'Sabrina'],
#  'ages': array([23, 29, 20, 32, 27, 27, 25, 25, 34, 31])}

# %% [markdown]
# ...                        ...         ...                 ...
# 26405                    25779         USA                 NaN
# 26406                    26219         USA             26219.0
# 26407                    26377         USA                 NaN
# 26408                    26444         USA             26444.0
# 26409                    28694         USA             28694.0
#
#        Females Average Times           City Country  Division  Gender  \
# 0                        NaN       Keringet     KEN         1       1
# 1                        NaN       Portland     USA         2       2
# 2                        NaN   Machida-City     JPN         3       3
# 3                        NaN  Mammoth Lakes     USA         4       4
# 4                        NaN       Marakwet     KEN         5       5
# ...                      ...            ...     ...       ...     ...
# 26405                25779.0        Ontario     USA       344   11972
# 26406                    NaN   Fayetteville     USA      4774   14436
# 26407                26377.0        Malvern     USA       698   11973
# 26408                    NaN       New York     USA      1043   14437
# 26409                    NaN     Alpharetta     USA      2553   14438
#
#                         Half M/F                      Name  Number of Records  \
# 0      12/30/1899 1:04:35 AM   M           Kirui, Geoffrey                  1
# 1      12/30/1899 1:04:35 AM   M               Rupp, Galen                  1
# 2      12/30/1899 1:04:36 AM   M             Osako, Suguru                  1
# 3      12/30/1899 1:04:45 AM   M          Biwott, Shadrack                  1
# 4      12/30/1899 1:04:35 AM   M            Chebet, Wilson                  1
# ...                      ...  ..                       ...                ...
# 26405  12/30/1899 3:23:31 AM   F  Steinbach, Paula Eyvonne                  1
# 26406  12/30/1899 3:00:26 AM   M        Avelino, Andrew R.                  1
# 26407  12/30/1899 3:36:24 AM   F           Hantel, Johanna                  1
# 26408  12/30/1899 3:22:30 AM   M              Reilly, Bill                  1
# 26409  12/30/1899 3:08:16 AM   M             Rigsby, Scott                  1
#
#                Official Time  Overall                    Pace State
# 0      12/30/1899 2:09:37 AM        1  12/30/1899 12:04:57 AM   NaN
# 1      12/30/1899 2:09:58 AM        2  12/30/1899 12:04:58 AM    OR
# 2      12/30/1899 2:10:28 AM        3  12/30/1899 12:04:59 AM   NaN
# 3      12/30/1899 2:12:08 AM        4  12/30/1899 12:05:03 AM    CA
# 4      12/30/1899 2:12:35 AM        5  12/30/1899 12:05:04 AM   NaN
# ...                      ...      ...                     ...   ...
# 26405  12/30/1899 7:09:39 AM    26407  12/30/1899 12:16:24 AM    CA
# 26406  12/30/1899 7:16:59 AM    26408  12/30/1899 12:16:40 AM    NC
# 26407  12/30/1899 7:19:37 AM    26409  12/30/1899 12:16:47 AM    PA
# 26408  12/30/1899 7:20:44 AM    26410  12/30/1899 12:16:49 AM    NY
# 26409  12/30/1899 7:58:14 AM    26411  12/30/1899 12:18:15 AM    GA
#
# [26410 rows x 26 columns]

# %% [markdown]
# ### In-Class Exercise #1 - Read in Boston Red Sox Hitting Data <br>
# <p>Use the pandas read_csv() method to read in the statistics from the two files yesterday.</p>

# %%
sox17 = pd.read_csv('../day_1/in_class/files/redsox_2017_hitting.txt', sep=',')
sox18 = pd.read_csv('../day_1/in_class/files/redsox_2018_hitting.txt', sep=',')

display(sox17)
display(sox18)
# Out:
#     Rk Pos                Name  Age    G   PA   AB    R    H  2B
# 15  ...   8   17  0.246  0.329  0.415  0.744   100   27    0    0   0   0    0
# 16  ...   2   10  0.222  0.263  0.389  0.652    73   14    1    0   0   0    0
# 17  ...   4    7  0.130  0.259  0.261  0.520    42    6    1    0   0   0    0
# 18  ...   2    1  0.091  0.231  0.091  0.322    -7    1    0    0   0   0    0
# 19  ...   0    2  0.167  0.143  0.167  0.310   -17    1    0    0   0   1    0
#
# [20 rows x 28 columns]

# %% [markdown]
# ### Accessing Data <br>

# %% [markdown]
# ##### Indexing
#
# <p>You can directly select a column of a dataframe just like you would a dict. The result is a Pandas 'Series' object.</p>

# %%
data_ages = data['ages']

print(data_ages)


# print out the type of the variable data
# Series
print(type(data_ages))
# DataFrame
print(type(data))

# DataSeries Index - starting at 0 
data_ages[1]

# key first, row index second
data['names'][1]

# print(float(data_ages[0]))
# print(data_ages)
data
# Out:
# 0    23
# 1    29
# 2    20
# 3    32
# 4    27
# 5    27
# 6    25
# 7    25
# 8    34
# 9    31
# Name: ages, dtype: int64
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
#      names  ages
# 0    Alice    23
# 1      Bob    29
# 2    James    20
# 3     Beth    32
# 4     John    27
# 5    Sally    27
# 6  Richard    25
# 7   Lauren    25
# 8  Brandon    34
# 9  Sabrina    31

# %% [markdown]
# ##### df.loc

# %% [markdown]
# <p>Along the horizontal dimension, rows of Pandas DataFrames are Row objects. You will notice there is a third column present in the DataFrame - this is the $\textit{index}$. It is automatically generated as a row number, but can be reassigned to a column of your choice using the DataFrame.set_index(colname) method. We can use it to access particular Pandas $\textit{rows}$, which are also Series objects:</p>

# %%
# Grab the first row of data -- by the index of the row
my_row = data.loc[2]
print(f"\nLocation of the 3rd row in data: {my_row}")
# Getting Multiple values from a df.loc
multiple_peeps = data.loc[ 0:4 ]['names']
print(f"\nHere are the multiple peeps", multiple_peeps)

# Using df.loc and producing a Dataframe at the end
print('\nSlice of the dataframe')
multi_peeps_df = data.loc[6:][['names','ages']]
display(multi_peeps_df)


# Reset our my_people dataframe index
name_as_index = data.loc[[1,3,5,7,9]][['names','ages']].set_index('names')
display(name_as_index)


# reset_index.reset_index()



# print(reset_index.loc['James'])
# print(data.loc[2])
# Out:
# Location of the 3rd row in data: names    James
# ages        20
# Name: 2, dtype: object
#
# Here are the multiple peeps 0    Alice
# 1      Bob
# 2    James
# 3     Beth
# 4     John
# Name: names, dtype: object
#
# Slice of the dataframe
#      names  ages
# 6  Richard    25
# 7   Lauren    25
# 8  Brandon    34
# 9  Sabrina    31
#          ages
# names
# Bob        29
# Beth       32
# Sally      27
# Lauren     25
# Sabrina    31

# %% [markdown]
# ##### keys()

# %%
# Access all of the keys/columns of the dataframe
# Dataframe.keys()

print(data.keys())
print(type(sox17.keys()))
print(type(sox17.keys().tolist()))
# Out:
# Index(['names', 'ages'], dtype='object')
# <class 'pandas.core.indexes.base.Index'>
# <class 'list'>

# %% [markdown]
# ##### Slicing a DataFrame

# %%
# printing all data for context
data[2:5]
# Out:
#    names  ages
# 2  James    20
# 3   Beth    32
# 4   John    27

# %% [markdown]
# ### Built-In Methods <br>
#
# <p>These are methods that are frequently used when using Pandas to make your life easier. It is possible to spend a whole week simply exploring the built-in functions supported by DataFrames in Pandas. Here however, we will simply highlight a few ones that might be useful, to give you an idea of what's possible out of the box with Pandas:</p>

# %% [markdown]
# ##### head()

# %%
# DataFrame.head()  -- Accepts integer parameter(gives access to more rows)
sox17.head()
# Out:
#    Rk Pos               Name  Age    G   PA   AB   R    H  2B  3B  HR  RBI  \
# 0   1   C  Christian Vazquez   26   99  345  324  43   94  18   2   5   32
# 1   2  1B     Mitch Moreland   31  149  576  508  73  125  34   0  22   79
# 2   3  2B     Dustin Pedroia   33  105  463  406  46  119  19   0   7   62
# 3   4  SS    Xander Bogaerts   24  148  635  571  94  156  32   6  10   62
# 4   5  3B      Rafael Devers   20   58  240  222  34   63  14   0  10   30
#
#    ...  BB   SO     BA    OBP    SLG    OPS  OPS+   TB  GDP  HBP  SH  SF  IBB
# 0  ...  17   64  0.290  0.330  0.404  0.735    91  131   14    3   0   1    0
# 1  ...  57  120  0.246  0.326  0.443  0.769    99  225   14    6   0   5    6
# 2  ...  49   48  0.293  0.369  0.392  0.760   100  159   11    2   2   4    4
# 3  ...  56  116  0.273  0.343  0.403  0.746    95  230   17    6   0   2    6
# 4  ...  18   57  0.284  0.338  0.482  0.819   111  107    5    0   0   0    3
#
# [5 rows x 28 columns]

# %% [markdown]
# ##### tail()

# %%
# DataFrame.tail()  -- Accepts integer parameter(gives access to more rows)
sox17.tail()
# Out:
#     Rk Pos             Name  Age   G  PA  AB  R   H  2B  3B  HR  RBI  ...  BB  \
# 18  19  IF  Marco Hernandez   24  21  60  58  7  16   3   0   0    2  ...   1
# 19  20  UT      Rajai Davis   36  17  38  36  7   9   2   0   0    2  ...   1
# 20  21  UT     Steve Selsky   27   8   9   9  0   1   1   0   0    0  ...   0
# 21  22  UT    Blake Swihart   25   6   7   5  1   1   0   0   0    0  ...   2
# 22  23  2B   Chase d'Arnaud   30   2   1   1  2   1   0   0   0    0  ...   0
#
#     SO     BA    OBP    SLG    OPS  OPS+  TB  GDP  HBP  SH  SF  IBB
# 18  15  0.276  0.300  0.328  0.628    65  19    0    1   0   0    0
# 19  13  0.250  0.289  0.306  0.595    56  11    2    1   0   0    0
# 20   5  0.111  0.111  0.222  0.333   -16   2    0    0   0   0    0
# 21   3  0.200  0.429  0.200  0.629    74   1    0    0   0   0    0
# 22   0  1.000  1.000  1.000  2.000   428   1    0    0   0   0    0
#
# [5 rows x 28 columns]

# %% [markdown]
# ##### shape

# %%
# The dataframe has a shape property, just like a NumPy matrix. 
# print(df.shape) -- DataFrame.shape -- No Parameter

sox17.shape
# Out:
# (23, 28)

# %% [markdown]
# ##### describe() <br>
# <p>Probably one of the most important methods to understand...</p>

# %%
# Collect summary statistics in one line
# DataFrame.describe() -- Accepts parameters (include, exclude)
sox17.describe()
# Out:
#              Rk        Age           G          PA          AB           R  \
# count  23.00000  23.000000   23.000000   23.000000   23.000000   23.000000
# mean   12.00000  27.478261   72.086957  274.565217  245.521739   34.130435
# std     6.78233   4.110624   52.747178  236.592059  209.032157   30.804817
# min     1.00000  20.000000    2.000000    1.000000    1.000000    0.000000
# 25%     6.50000  24.000000   28.500000   74.500000   67.000000    8.500000
# 50%    12.00000  27.000000   64.000000  188.000000  171.000000   30.000000
# 75%    17.50000  30.000000  119.000000  502.000000  444.000000   52.000000
# max    23.00000  36.000000  153.000000  712.000000  628.000000  101.000000
#
#                 H         2B         3B         HR         RBI         SB  \
# count   23.000000  23.000000  23.000000  23.000000   23.000000  23.000000
# mean    63.434783  13.086957   0.826087   7.304348   31.956522   4.608696
# std     55.645653  12.630817   1.466355   8.309003   32.031913   6.867176
# min      1.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# 25%     18.000000   2.000000   0.000000   0.000000    2.000000   0.000000
# 50%     53.000000  12.000000   0.000000   5.000000   27.000000   2.000000
# 75%    118.500000  19.000000   1.500000  10.000000   62.000000   5.500000
# max    166.000000  46.000000   6.000000  24.000000  102.000000  26.000000
#
#               CS         BB          SO         BA        OBP        SLG  \
# count  23.000000  23.000000   23.000000  23.000000  23.000000  23.000000
# mean    1.347826  24.826087   52.869565   0.278435   0.346217   0.393348
# std     1.335144  24.579467   41.351382   0.163040   0.153742   0.156269
# min     0.000000   0.000000    0.000000   0.111000   0.111000   0.200000
# 25%     0.000000   6.000000   20.000000   0.224500   0.298500   0.330500
# 50%     1.000000  17.000000   48.000000   0.250000   0.325000   0.387000
# 75%     2.000000  48.500000   76.500000   0.274500   0.348000   0.426500
# max     5.000000  77.000000  124.000000   1.000000   1.000000   1.000000
#
#              OPS        OPS+          TB        GDP        HBP         SH  \
# count  23.000000   23.000000   23.000000  23.000000  23.000000  23.000000
# mean    0.739609   93.521739  100.086957   6.130435   2.304348   0.347826
# std     0.298278   78.686299   91.930267   5.786382   2.566122   0.775107
# min     0.333000  -16.000000    1.000000   0.000000   0.000000   0.000000
# 25%     0.625000   63.000000   22.500000   1.500000   0.000000   0.000000
# 50%     0.709000   88.000000   89.000000   4.000000   2.000000   0.000000
# 75%     0.764500   99.500000  176.500000  10.000000   3.000000   0.000000
# max     2.000000  428.000000  288.000000  17.000000   9.000000   3.000000
#
#               SF        IBB
# count  23.000000  23.000000
# mean    1.565217   2.086957
# std     2.149547   3.073539
# min     0.000000   0.000000
# 25%     0.000000   0.000000
# 50%     1.000000   0.000000
# 75%     2.000000   4.000000
# max     8.000000   9.000000

# %% [markdown]
# ##### sort_values()

# %%
# Sort based on many labels, with left-to-right priority
# sorted_data = data.sort_values('ages').reset_index()

# DataFrame.sort_values('key')

sorted_data = data.sort_values('ages', kind='mergesort').reset_index(drop=True)
display(sorted_data)
# Out:
#      names  ages
# 0    James    20
# 1    Alice    23
# 2  Richard    25
# 3   Lauren    25
# 4     John    27
# 5    Sally    27
# 6      Bob    29
# 7  Sabrina    31
# 8     Beth    32
# 9  Brandon    34

# %% [markdown]
# ##### .columns

# %%
# will show all cols headers
# DataFrame.columns -- has no parameters

print(sox17.columns)
print(f'\n The type of bos17.columns: {type(sox17.columns)}')

print(sox17.keys())
print(f'\n The type of bos17.keys(): {type(sox17.keys())}')
# Out:
# Index(['Rk', 'Pos', 'Name', 'Age', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR',
#        'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+', 'TB',
#        'GDP', 'HBP', 'SH', 'SF', 'IBB'],
#       dtype='object')
#
#  The type of bos17.columns: <class 'pandas.core.indexes.base.Index'>
# Index(['Rk', 'Pos', 'Name', 'Age', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR',
#        'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+', 'TB',
#        'GDP', 'HBP', 'SH', 'SF', 'IBB'],
#       dtype='object')
#
#  The type of bos17.keys(): <class 'pandas.core.indexes.base.Index'>

# %% [markdown]
# ### In-Class Exercise #2 - Describe & Sort Boston Red Sox Hitting Data <br>
# <p>Take the data that you read in earlier from the Red Sox csv's and use the describe method to understand the data better. Compare the two years and decide which team is having the better year. Then sort the values based on Batting Average.</p>

# %%
ba17 = sox17.describe()['BA']['mean']
ba18 = sox18.describe()['BA']['mean']
if ba17 > ba18:
    print('17 is better')
else:
    print('18 is better')
# Out:
# 17 is better

# %% [markdown]
# ### Filtration <br>
# <p>Let's look at how to filter dataframes for rows that fulfill a specific conditon.</p>

# %% [markdown]
# ##### Conditionals

# %%
# Conditional boolean dataframe
data['ages'] >= 25
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: ages, dtype: bool

# %% [markdown]
# ##### Subsetting

# %%
# exactly like numpy
data[data['ages'] >= 25]
# Out:
#      names  ages
# 1      Bob    29
# 3     Beth    32
# 4     John    27
# 5    Sally    27
# 6  Richard    25
# 7   Lauren    25
# 8  Brandon    34
# 9  Sabrina    31

# %% [markdown]
# ### Column Transformations <br>
# <p>Rarely, if ever, will the columns in the original raw dataframe read from CSV or database table be the ones you actually need for your analysis. You will spend lots of time constantly transforming columns or groups of columns using general computational operations to produce new ones that are functions of the old ones. Pandas has full support for this: Consider the following dataframe containing membership term and renewal number for a group of customers:</p>

# %%
# Generate some fake data
customer_id = np.random.randint(1000,1100, 10)
renewal_nbr = np.random.randint(0,10,10)
customer_dict = {1: 0.5, 0: 1}
terms_in_years = [customer_dict[key] for key in np.random.randint(0,2,10)]

random_data = {
    'customer_id': customer_id,
    'renewal_nbr': renewal_nbr,
    'term_in_years': terms_in_years
}

customers = pd.DataFrame.from_dict(random_data)
customers
# Out:
#    customer_id  renewal_nbr  term_in_years
# 0         1055            0            1.0
# 1         1088            7            1.0
# 2         1006            2            0.5
# 3         1072            0            0.5
# 4         1096            1            1.0
# 5         1064            5            0.5
# 6         1024            9            0.5
# 7         1038            6            0.5
# 8         1011            3            1.0
# 9         1022            1            1.0

# %% [markdown]
# ##### Generating a New Column w/Data

# %%
# DataFrame['key'] = Some Calculation from our DataFrame Columns
customers['customer_tenure'] = customers['renewal_nbr']*customers['term_in_years']

display(customers)
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure
# 0         1055            0            1.0              0.0
# 1         1088            7            1.0              7.0
# 2         1006            2            0.5              1.0
# 3         1072            0            0.5              0.0
# 4         1096            1            1.0              1.0
# 5         1064            5            0.5              2.5
# 6         1024            9            0.5              4.5
# 7         1038            6            0.5              3.0
# 8         1011            3            1.0              3.0
# 9         1022            1            1.0              1.0

# %% [markdown]
# ##### User Defined Function
#
# <p>If what you want to do to a column that can't be represented by simple mathematical operations, you can write your own $\textit{user defined function}$ with the full customizability available in Python and any external Python packages, then map it directly onto a column. Let's add some ages to our customer dataframe, and then classify them into our custom defined grouping scheme:</p>

# %%
# use .apply to map over dataframe



# Create a new column for ages
customers['ages'] = np.random.randint(18,70,10)
display(customers)
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure  ages
# 0         1055            0            1.0              0.0    30
# 1         1088            7            1.0              7.0    19
# 2         1006            2            0.5              1.0    64
# 3         1072            0            0.5              0.0    66
# 4         1096            1            1.0              1.0    57
# 5         1064            5            0.5              2.5    65
# 6         1024            9            0.5              4.5    60
# 7         1038            6            0.5              3.0    66
# 8         1011            3            1.0              3.0    60
# 9         1022            1            1.0              1.0    29

# %%
def make_age_groups(age):
    if age < 20:
        return ('"Teenager"')
    elif age <= 35:
        return 'Young Adult'
    elif age < 65:
        return 'Adult'
    elif age >= 65:
        return 'Senior'
    
customers['age_group']= customers['ages'].apply(make_age_groups)
customers
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure  ages    age_group
# 0         1055            0            1.0              0.0    30  Young Adult
# 1         1088            7            1.0              7.0    19   "Teenager"
# 2         1006            2            0.5              1.0    64        Adult
# 3         1072            0            0.5              0.0    66       Senior
# 4         1096            1            1.0              1.0    57        Adult
# 5         1064            5            0.5              2.5    65       Senior
# 6         1024            9            0.5              4.5    60        Adult
# 7         1038            6            0.5              3.0    66       Senior
# 8         1011            3            1.0              3.0    60        Adult
# 9         1022            1            1.0              1.0    29  Young Adult

# %% [markdown]
# <p>As a last example I'll show here how you would use a lambda function to create a UDF that depends on $\textit{more than one}$ column:</p>
#
# <li>UDF = User Defined Function</li>

# %%
#Axis for apply can only be 1 or 0 -- 1 being the X axis 0 being the Y axis
def make_loyalty_age_group(row):
    age = row['ages']
    tenure = row['customer_tenure']
    
    if age < 20:
        age_group = "Teenager"
    elif age <= 35:
        age_group = 'Young Adult'
    elif age < 65:
        age_group = 'Adult'
    elif age >= 65:
        age_group = 'Senior'
        
    if tenure > 2.0:
        loyalty_age_group = f'Loyal {age_group}'
    else:
        loyalty_age_group = f'New {age_group}'
    
    return loyalty_age_group

customers['loyalty_age_group'] = customers.apply(make_loyalty_age_group, axis='columns')

display(customers)
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure  ages  \
# 0         1055            0            1.0              0.0    30
# 1         1088            7            1.0              7.0    19
# 2         1006            2            0.5              1.0    64
# 3         1072            0            0.5              0.0    66
# 4         1096            1            1.0              1.0    57
# 5         1064            5            0.5              2.5    65
# 6         1024            9            0.5              4.5    60
# 7         1038            6            0.5              3.0    66
# 8         1011            3            1.0              3.0    60
# 9         1022            1            1.0              1.0    29
#
#      age_group loyalty_age_group
# 0  Young Adult   New Young Adult
# 1   "Teenager"    Loyal Teenager
# 2        Adult         New Adult
# 3       Senior        New Senior
# 4        Adult         New Adult
# 5       Senior      Loyal Senior
# 6        Adult       Loyal Adult
# 7       Senior      Loyal Senior
# 8        Adult       Loyal Adult
# 9  Young Adult   New Young Adult

# %% [markdown]
# ### In-Class Exercise #3 - Create Your Own UDF <br>
# <p>Using the Boston Red Sox data, create your own UDF which creates a new column called 'All-Star' and puts every player with either a batting average over .280 or an on base percentage of over .360 with a result of 'Yes' in the column and 'No' if not.</p>

# %%
"""
    Name  BA OBP AllStar
    --------------------
    Name .233 .360 Yes
    Name .150 .288 No
"""

all_star = sox17[['Name','BA', 'OBP']]

all_star.loc[(all_star['BA'] > 0.28) & (all_star['OBP'] > 0.36)]
# Out:
#               Name     BA    OBP
# 2   Dustin Pedroia  0.293  0.369
# 22  Chase d'Arnaud  1.000  1.000

# %%
def make_all_star(row):
    ba = row['BA']
    obp = row['OBP']
    
    if ba > 0.280 or obp > 0.360:
        all_star = 'Yes'
    else:
        all_star = 'No'
        
    return all_star

sox17['AllStar'] = sox17.apply(make_all_star, axis = 1)
print(sox17[ ['Name','BA','OBP','AllStar'] ])
# Out:
#                   Name     BA    OBP AllStar
# 0    Christian Vazquez  0.290  0.330     Yes
# 1       Mitch Moreland  0.246  0.326      No
# 2       Dustin Pedroia  0.293  0.369     Yes
# 3      Xander Bogaerts  0.273  0.343      No
# 4        Rafael Devers  0.284  0.338     Yes
# 5    Andrew Benintendi  0.271  0.352      No
# 6   Jackie Bradley Jr.  0.245  0.323      No
# 7         Mookie Betts  0.264  0.344      No
# 8       Hanley Ramirez  0.242  0.320      No
# 9           Sandy Leon  0.225  0.290      No
# 10         Chris Young  0.235  0.322      No
# 11       Deven Marrero  0.211  0.259      No
# 12       Eduardo Nunez  0.321  0.353     Yes
# 13          Brock Holt  0.200  0.305      No
# 14       Josh Rutledge  0.224  0.297      No
# 15      Pablo Sandoval  0.212  0.269      No
# 16          Sam Travis  0.263  0.325      No
# 17         Tzu-Wei Lin  0.268  0.369     Yes
# 18     Marco Hernandez  0.276  0.300      No
# 19         Rajai Davis  0.250  0.289      No
# 20        Steve Selsky  0.111  0.111      No
# 21       Blake Swihart  0.200  0.429     Yes
# 22      Chase d'Arnaud  1.000  1.000     Yes

# %% [markdown]
# ### Aggregations <br>
# <p>The raw data plus some transformations is generally only half the story. Your objective is to extract actual insights and actionable conclusions from the data, and that means reducing it from potentially billions of rows to some summary statistics via aggregation functions.</p>

# %% [markdown]
# ##### groupby() <br>
# <p>The .groupby() function is in some ways a 'master' aggregation.</p>
#
# <p>Data tables will usually reserve one column as a primary key - that is, a column for which each row has a unique value. This is to facilitate access to the exact rows of a data table that a user wants to view. The other columns will often have repeated values, such as the age groups in the above examples. We can use these columns to explore the data using the Pandas API:</p>

# %%
# also introducing .count() here, exact same as to how it's used in SQL

# Using the groupby with the column intact as a column/key
# customers.groupby('age_group', as_index = False).count()[['customer_id','age_group']]
customers.groupby('age_group').count()
#customers.groupby('age_group', as_index=False).count()
# Out:
#              customer_id  renewal_nbr  term_in_years  customer_tenure  ages  \
# age_group
# "Teenager"             1            1              1                1     1
# Adult                  4            4              4                4     4
# Senior                 3            3              3                3     3
# Young Adult            2            2              2                2     2
#
#              loyalty_age_group
# age_group
# "Teenager"                   1
# Adult                        4
# Senior                       3
# Young Adult                  2

# %% [markdown]
# ##### Type of groupby()
#
# <p>The result is a new dataframe, the columns of which all contain the counts of the grouped field. Notice the type of a grouped dataframe:</p>

# %%
print(type(customers), 'Regular Data Frame')
print(f'\n Type of Group By for Customer.GroupBy: {type(customers.groupby("age_group"))}')
# Out:
# <class 'pandas.core.frame.DataFrame'> Regular Data Frame
#
#  Type of Group By for Customer.GroupBy: <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %% [markdown]
# <p>This is because simply grouping data doesn't quite make sense without an aggregation function like count() to pair with. In this case, we're counting occurances of the grouped field, but that's not all we can do. We can take averages, standard deviations, mins, maxes and much more! Let's see how this works a bit more:</p>

# %% [markdown]
# ##### mean()

# %%
# mean = average
customers.groupby('age_group').mean()[['customer_tenure','ages']]
# Out:
#              customer_tenure       ages
# age_group
# "Teenager"          7.000000  19.000000
# Adult               2.375000  60.250000
# Senior              1.833333  65.666667
# Young Adult         0.500000  29.500000

# %% [markdown]
# ##### groupby() w/Multiple Columns
#
# <p>We end up with the average age of the groups in the last column, the average tenure in the tenure column, and so on and so forth. You can even split the groups more finely by passing a list of columns to group by:</p>

# %%
customers.groupby(['age_group','ages']).mean().sort_values('ages',ascending=False)
# Out:
#                   customer_id  renewal_nbr  term_in_years  customer_tenure
# age_group   ages
# Senior      66         1055.0          3.0           0.50             1.50
#             65         1064.0          5.0           0.50             2.50
# Adult       64         1006.0          2.0           0.50             1.00
#             60         1017.5          6.0           0.75             3.75
#             57         1096.0          1.0           1.00             1.00
# Young Adult 30         1055.0          0.0           1.00             0.00
#             29         1022.0          1.0           1.00             1.00
# "Teenager"  19         1088.0          7.0           1.00             7.00

# %% [markdown]
# ##### drop_duplicates()
#
# <p>Drops all duplicates from the current dataframe</p>

# %%
customers
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure  ages  \
# 0         1055            0            1.0              0.0    30
# 1         1088            7            1.0              7.0    19
# 2         1006            2            0.5              1.0    64
# 3         1072            0            0.5              0.0    66
# 4         1096            1            1.0              1.0    57
# 5         1064            5            0.5              2.5    65
# 6         1024            9            0.5              4.5    60
# 7         1038            6            0.5              3.0    66
# 8         1011            3            1.0              3.0    60
# 9         1022            1            1.0              1.0    29
#
#      age_group loyalty_age_group
# 0  Young Adult   New Young Adult
# 1   "Teenager"    Loyal Teenager
# 2        Adult         New Adult
# 3       Senior        New Senior
# 4        Adult         New Adult
# 5       Senior      Loyal Senior
# 6        Adult       Loyal Adult
# 7       Senior      Loyal Senior
# 8        Adult       Loyal Adult
# 9  Young Adult   New Young Adult

# %%
customers_copy = customers.drop_duplicates('renewal_nbr').reset_index(drop=True)
customers_copy
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure  ages  \
# 0         1055            0            1.0              0.0    30
# 1         1088            7            1.0              7.0    19
# 2         1006            2            0.5              1.0    64
# 3         1096            1            1.0              1.0    57
# 4         1064            5            0.5              2.5    65
# 5         1024            9            0.5              4.5    60
# 6         1038            6            0.5              3.0    66
# 7         1011            3            1.0              3.0    60
#
#      age_group loyalty_age_group
# 0  Young Adult   New Young Adult
# 1   "Teenager"    Loyal Teenager
# 2        Adult         New Adult
# 3        Adult         New Adult
# 4       Senior      Loyal Senior
# 5        Adult       Loyal Adult
# 6       Senior      Loyal Senior
# 7        Adult       Loyal Adult

# %%
# Send customer data into a CSV file
customers_copy.to_csv('../files/customers.csv')

# %% [markdown]
# <p>Thus the groupby operation allows you to rapidly make summary observations about the state of your entire dataset at flexible granularity. In one line above, we actually did something very complicated - that's the power of the dataframe. In fact, the process often consists of several iterative groupby operations, each revealing greater insight than the last - if you don't know where to start with a dataset, try a bunch of groupbys!</p>

# %% [markdown]
# ### Homework Excersise #1 - Find the Total Number of Runs and RBIs for the Red Sox <br>
# <p>Get total number of home runs and rbi's</p>

# %%
# step 1: Add a new column with the key 'Team' and all column values should be 'BOS'

# step 2: Group by the 'Team' column and get total home runs and rbi's

# Produce data for both 2017 and 2018 (ie print both seperated by a newline character \n)

"""
TEAM    HR   RBI
----------------
BOS     144  538
"""

sox17['Team']='BOS'
display(sox17.groupby('Team')[['HR','RBI']].sum())

sox18['Team']='BOS'
display(sox18.groupby('Team')[['HR','RBI']].sum())
# Out:
#        HR  RBI
# Team
# BOS   168  735
#        HR  RBI
# Team
# BOS   208  826

# %% [markdown]
# ## Find the average age of runners in the 2017 Boston Marathon

# %%
marathon['Age'].mean()
# Out:
# 42.587731919727375
